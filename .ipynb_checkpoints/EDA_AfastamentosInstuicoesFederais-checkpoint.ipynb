# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('Datasets/AFASTREM_022021.csv', sep=';', encoding='latin1')

# %% [markdown]
# ## Data information

# %%
df.head(5)
# Out:
#                                                 Nome          CPF  \
# 0  SONIA CANDIDA BATISTA                         ...  ***086171**
# 1  MARIA GRACI DA CONCEICAO MAXIMA               ...  ***803611**
# 2  DOMINGOS SAVIO RODRIGUES                      ...  ***829911**
# 3  CLEUSA ADELAIDE MOREIRA MARINO                ...  ***530959**
# 4  NESTOR BATISTA DE OLIVEIRA                    ...  ***197415**
#
#                  Descrição do cargo emprego  \
# 0  CONTADOR
# 1  AGENTE DE PORTARIA
# 2  AGENTE ADMINISTRATIVO
# 3  AGENTE ADMINISTRATIVO
# 4  AGENTE DE PORTARIA
#
#                     Nome do órgão de origem UF da UPAG de vinculação  \
# 0  MINIST.DA AGRICULTURA,PECUARIA E ABAST.                        DF
# 1  MINIST.DA AGRICULTURA,PECUARIA E ABAST.                        DF
# 2  MINIST.DA AGRICULTURA,PECUARIA E ABAST.                        DF
# 3  MINIST.DA AGRICULTURA,PECUARIA E ABAST.                        DF
# 4  MINIST.DA AGRICULTURA,PECUARIA E ABAST.                        DF
#
#              Cidade da residência Nível escolaridade  \
# 0  BRASILIA                                       NS
# 1  BRASILIA                                       NI
# 2  BRASILIA                                       NI
# 3  BRASILIA                                       NI
# 4  BRASILIA                                       NI
#
#    Ano/Mês início afastamento  Ano/Mês referência Valor rendimento liquido  \
# 0                      201005              202102                 11540,22
# 1                      201703              202102                  5944,60
# 2                      200705              202102                  6051,50
# 3                      200705              202102                  3168,98
# 4                      200705              202102                  6432,50
#
#                             Descrição do afastamento  \
# 0  CESSAO (COM ONUS) PARA OUTROS ORGAOS - EST    ...
# 1  CESSAO (COM ONUS) PARA OUTROS ORGAOS - EST    ...
# 2  CESSAO (SEM ONUS) PARA OUTROS ORGAOS - EST    ...
# 3  CESSAO (SEM ONUS) PARA OUTROS ORGAOS - EST    ...
# 4  CESSAO (SEM ONUS) PARA OUTROS ORGAOS - EST    ...
#
#
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120741 entries, 0 to 120740
# Data columns (total 12 columns):
#  #   Column                                                       Non-Null Count   Dtype
# ---  ------                                                       --------------   -----
#  0   Nome                                                         120741 non-null  object
#  1   CPF                                                          120741 non-null  object
#  2   Descrição do cargo emprego                                   120741 non-null  object
#  3   Nome do órgão de origem                                      120741 non-null  object
#  4   UF da UPAG de vinculação                                     120741 non-null  object
#  5   Cidade da residência                                         120741 non-null  object
#  6   Nível escolaridade                                           113171 non-null  object
#  7   Ano/Mês início afastamento                                   120741 non-null  int64
#  8   Ano/Mês referência                                           120741 non-null  int64
#  9   Valor rendimento liquido                                     120741 non-null  object
#  10  Descrição do afastamento                                     120741 non-null  object
#  11                                                               0 non-null       float64
# dtypes: float64(1), int64(2), object(9)
# memory usage: 11.1+ MB

# %%
df.describe()
# Out:
#        Ano/Mês início afastamento  Ano/Mês referência  \
# count               120741.000000            120741.0
# mean                201802.687140            202102.0
# std                    429.721761                 0.0
# min                 198102.000000            202102.0
# 25%                 201705.000000            202102.0
# 50%                 202007.000000            202102.0
# 75%                 202101.000000            202102.0
# max                 202102.000000            202102.0
#
#
# count                                                0.0
# mean                                                 NaN
# std                                                  NaN
# min                                                  NaN
# 25%                                                  NaN
# 50%                                                  NaN
# 75%                                                  NaN
# max                                                  NaN

# %%
df.columns
# Out:
# Index(['Nome', 'CPF', 'Descrição do cargo emprego', 'Nome do órgão de origem',
#        'UF da UPAG de vinculação', 'Cidade da residência',
#        'Nível escolaridade', 'Ano/Mês início afastamento',
#        'Ano/Mês referência', 'Valor rendimento liquido',
#        'Descrição do afastamento',
#        '                                                           '],
#       dtype='object')

# %% [markdown]
# # Exploration Data Analysis

# %% [markdown]
# ### Quais orgãos Ferderais possuem a maior média Salarial por funcionarios Afastados?

# %%
df['Valor rendimento liquido'] = df['Valor rendimento liquido'].apply(lambda x: float(x.replace(',', '.')))

# %%
plt.rcdefaults()
plt.figure(figsize=(10,5))
plt.title('Média Salarial por funcionario afastado')
df.groupby('Nome do órgão de origem')['Valor rendimento liquido'].mean().sort_values(ascending=False)[:20].plot.bar();

# %% [markdown]
# ### Quais orgãos Ferderais possuem a maior quantidade de funcionarios Afastados?

# %%
plt.figure(figsize=(10,4))
plt.title('Qtd de Funcionarios afastado')
df.groupby('Nome do órgão de origem')['Nome'].count().sort_values(ascending = False)[:20].plot.bar();

# %% [markdown]
# ### Quais são os cargos com maior número de funcionarios afastados?

# %%
plt.figure(figsize=(10,5))
plt.title('Quais cargos com o maior número de funcionarios afastados')
df.groupby('Descrição do cargo emprego')['Nome'].count().sort_values(ascending=False)[:20].plot.bar();

# %% [markdown]
# ### Quais os principais motivos de afastamento

# %%
df['Descrição do afastamento'].value_counts()[:20].plot.bar();

# %% [markdown]
# ### Em Qual Mês houve o maior número de pessoas afastadas? E qual foi o principal  motivo?

# %%
df['AnoMes'] = df['Ano/Mês início afastamento'].apply(lambda x: str(x))
data = df['AnoMes'].value_counts()[:10]
data
# Out:
# 202102    28126
# 202101    15798
# 201009     8137
# 200908     6277
# 202003     6255
# 202012     4017
# 202007     3010
# 201902     2729
# 202008     2710
# 202010     2428
# Name: AnoMes, dtype: int64

# %%
f, ax  = plt.subplots(figsize=(8,5))
sns.barplot(x=data.keys(), y=data.values, ax=ax);
plt.title('Meses com os maiores números de afastamento');

# %%
data = df[df['AnoMes'] == '202102']['Descrição do afastamento'].value_counts()[:10]
plt.figure(figsize=(8,5))
sns.barplot(x = data.keys(), y=data.values)
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# ### Qual é a quantidade e porcentagem de funcionarios com mais de 6 meses de afastamentos?

# %%
df['Data Referencia'] = pd.to_datetime(df['Ano/Mês referência'].apply(lambda x: str(x)).str.slice(stop=4)+"-"+ df['Ano/Mês referência'].apply(lambda x: str(x)).str.slice(start=-2)+"-"+'01')
df['Data Afastamento'] = pd.to_datetime(df['AnoMes'].str.slice(stop=4)+"-"+ df['AnoMes'].str.slice(start=-2)+"-"+'01')
df['Meses Afastado'] = round((df['Data Referencia'] - df['Data Afastamento']) / np.timedelta64(1, "M"))

# %%
df[df['Meses Afastado'] > 6]['Nome'].count() / df.shape[0]
# Out:
# 0.5245939655957794

# %%
df[df['Meses Afastado'] > 6]['Nome'].count()
# Out:
# 63340

# %%
data = df['Meses Afastado'].value_counts()
plt.figure(figsize=(8,5))
sns.lineplot(x=data.keys(), y=data.values)
plt.xlabel('Qtd de Meses Afastado')
plt.ylabel('Qtd de Funcionarios Afastados')
plt.title('Qtd de Meses de Funcionarios Afastados')
plt.show()

# %%
df_6_meses =  df[df['Meses Afastado'] > 6]

# %%
x = df_6_meses['Descrição do afastamento'].value_counts()[:10]
plt.figure(figsize=(8,5))
sns.barplot(x= x.keys(), y= x.values)
plt.xticks(rotation=90)
plt.title('Principais motivos de afastamentos com mais de 6 meses')
plt.xlabel('Qtd de funcionarios')
plt.show()

# %% [markdown]
# ### Qual e a quantidade e porcentagem de funciorais afastados a mais de um ano?

# %%
df['Anos Afastado'] = round((df['Data Referencia'] - df['Data Afastamento']) / np.timedelta64(1, "Y"))
df[df['Anos Afastado']>1]['Nome'].count() / df.shape[0]
# Out:
# 0.3702387755609114

# %%
df[df['Anos Afastado']>1]['Nome'].count()
# Out:
# 44703

# %%
data = df[df['Anos Afastado']>1]['Anos Afastado'].value_counts()
plt.figure(figsize=(8,5))
sns.lineplot(x=data.keys(), y=data.values)
plt.title('Quantidade de Funcionarios Afastados com mais de Um ano')
plt.ylabel('Qtd de Funcionarios')
plt.xlabel('Anos Afastado')
plt.show()
