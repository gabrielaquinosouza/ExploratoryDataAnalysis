# %% [markdown]
# ## Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('Datasets/demostrativo_acidentes.csv', sep=';', encoding='latin1')

# %% [markdown]
# ### Data Information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 703578 entries, 0 to 703577
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   Concessionaria            703578 non-null  object
#  1   Data                      703578 non-null  object
#  2   Horario                   703578 non-null  object
#  3   No_DaOcorrencia           703578 non-null  object
#  4   TipoDeOcorrencia          703575 non-null  object
#  5   Km                        703575 non-null  object
#  6   Trecho                    703578 non-null  object
#  7   Sentido                   701882 non-null  object
#  8   TipoDeAcidente            701867 non-null  object
#  9   Automovel                 546006 non-null  object
#  10  Bicicleta                 181556 non-null  float64
#  11  Caminhao                  318523 non-null  object
#  12  Moto                      254811 non-null  object
#  13  Onibus                    193660 non-null  float64
#  14  Outros                    223746 non-null  float64
#  15  Tracao_animal             159645 non-null  float64
#  16  Transp__Cargas_Especiais  85586 non-null   object
#  17  Trator__maquinas          142451 non-null  float64
#  18  Utilitario                181591 non-null  object
#  19  Ilesos                    699891 non-null  object
#  20  Levemente_feridos         311131 non-null  float64
#  21  Moderadamente_feridos     217031 non-null  float64
#  22  Gravemente_feridos        189968 non-null  float64
#  23  Mortos                    188295 non-null  float64
# dtypes: float64(9), object(15)
# memory usage: 128.8+ MB

# %%
df.describe()
# Out:
#            Bicicleta         Onibus         Outros  Tracao_animal  \
# count  181556.000000  193660.000000  223746.000000  159645.000000
# mean        0.042251       0.127770       0.277507       0.007705
# std         0.208504       0.353693       0.503119       0.088080
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         0.000000       0.000000       0.000000       0.000000
# 75%         0.000000       0.000000       1.000000       0.000000
# max         5.000000       6.000000       9.000000       3.000000
#
#        Trator__maquinas  Levemente_feridos  Moderadamente_feridos  \
# count     142451.000000      311131.000000          217031.000000
# mean           0.001804           0.810745               0.331635
# std            0.043256           1.058133               0.641015
# min            0.000000           0.000000               0.000000
# 25%            0.000000           0.000000               0.000000
# 50%            0.000000           1.000000               0.000000
# 75%            0.000000           1.000000               1.000000
# max            2.000000          51.000000              34.000000
#
#        Gravemente_feridos         Mortos
# count       189968.000000  188295.000000
# mean             0.103096       0.088255
# std              0.374760       0.355610
# min              0.000000       0.000000
# 25%              0.000000       0.000000
# 50%              0.000000       0.000000
# 75%              0.000000       0.000000
# max             27.000000      31.000000

# %%
df.head(10)
# Out:
#   Concessionaria      Data Horario No_DaOcorrencia TipoDeOcorrencia   Km  \
# 0             AF  01/01/10    0:38               3       sem vítima  314
# 1             AF  01/01/10   23:31             170       sem vítima  297
# 2             AF  01/01/10    6:39              14       sem vítima  230
# 3             AF  01/01/10    7:14              21       sem vítima  301
# 4             AF  01/01/10    8:56              41       com vítima  174
# 5             AF  02/01/10   12:05              85       com vítima  304
# 6             AF  02/01/10   13:05             100       sem vítima  269
# 7             AF  02/01/10   14:39             122       sem vítima  293
# 8             AF  02/01/10   16:11             148       com vítima   52
# 9             AF  02/01/10    1:02               4       sem vítima  309
#
#       Trecho Sentido           TipoDeAcidente Automovel  ...  Outros  \
# 0  BR-101/RJ     Sul           Saida de Pista       1.0  ...     NaN
# 1  BR-101/RJ     Sul         Colisão Traseira       NaN  ...     1.0
# 2  BR-101/RJ   Norte           Saida de Pista       1.0  ...     NaN
# 3  BR-101/RJ   Norte           Saida de Pista       1.0  ...     NaN
# 4  BR-101/RJ   Norte          Colisão Lateral       NaN  ...     1.0
# 5  BR-101/RJ   Norte  Atropelamento - Morador       1.0  ...     NaN
# 6  BR-101/RJ   Norte          Colisão Lateral       1.0  ...     NaN
# 7  BR-101/RJ   Norte          Colisão Lateral       2.0  ...     NaN
# 8  BR-101/RJ     Sul          Colisão Lateral       1.0  ...     NaN
# 9  BR-101/RJ   Norte  Atropelamento de Animal       1.0  ...     NaN
#
#   Tracao_animal Transp__Cargas_Especiais  Trator__maquinas  Utilitario  \
# 0           NaN                      NaN               NaN         NaN
# 1           NaN                      NaN               NaN         NaN
# 2           NaN                      NaN               NaN         NaN
# 3           NaN                      NaN               NaN         NaN
# 4           NaN                      NaN               NaN         NaN
# 5           NaN                      NaN               NaN         NaN
# 6           NaN                      NaN               NaN         NaN
# 7           NaN                      NaN               NaN         NaN
# 8           NaN                      NaN               NaN         NaN
# 9           NaN                      NaN               NaN         NaN
#
#    Ilesos Levemente_feridos  Moderadamente_feridos Gravemente_feridos Mortos
# 0       1               NaN                    NaN                NaN    NaN
# 1       2               NaN                    NaN                NaN    NaN
# 2       2               NaN                    NaN                NaN    NaN
# 3       2               NaN                    NaN                NaN    NaN
# 4       1               1.0                    1.0                NaN    NaN
# 5       3               NaN                    NaN                1.0    NaN
# 6       4               NaN                    NaN                NaN    NaN
# 7       5               NaN                    NaN                NaN    NaN
# 8       2               NaN                    2.0                NaN    NaN
# 9       1               NaN                    NaN                NaN    NaN
#
# [10 rows x 24 columns]

# %%
df.columns
# Out:
# Index(['Concessionaria', 'Data', 'Horario', 'No_DaOcorrencia',
#        'TipoDeOcorrencia', 'Km', 'Trecho', 'Sentido', 'TipoDeAcidente',
#        'Automovel', 'Bicicleta', 'Caminhao', 'Moto', 'Onibus', 'Outros',
#        'Tracao_animal', 'Transp__Cargas_Especiais', 'Trator__maquinas',
#        'Utilitario', 'Ilesos', 'Levemente_feridos', 'Moderadamente_feridos',
#        'Gravemente_feridos', 'Mortos'],
#       dtype='object')

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ### Qual e o Percentual de Acidentes com Vitimas?
# **<font color='red'>Cerca de 35% dos Acidentes envolve pelo menos uma Vitima</font>**

# %%
df['TipoDeOcorrencia'] = df['TipoDeOcorrencia'].apply(lambda x: str(x).upper())
df['Vitimas'] = df['TipoDeOcorrencia'].apply(lambda x: 1 if ('COM VÍTIMA' in x or 'COM VITIMA' in x
                                                             or 'COM MORTE' in x or 'FATAL' in x )else 0)

# %%
df['Vitimas'].value_counts( normalize=True)
# Out:
# 0    0.655764
# 1    0.344236
# Name: Vitimas, dtype: float64

# %%
plt.rcdefaults()
f, ax = plt.subplots(1,2, figsize=(10,5))
df['Vitimas'].value_counts().plot.pie(explode=[0,0.1], autopct='%1.1f%%', ax=ax[0], shadow=True)
ax[0].set_title('Vitimas')
ax[0].set_ylabel('')
sns.countplot('Vitimas', data= df, ax=ax[1])
ax[1].set_title('Vitimas')
plt.show()

# %% [markdown]
# ### Quais são as Três Concessionarias Reponsaveis pelos trechos  onde ocorrem o maior número acidentes com Vitimas?
# **<font color='red'>NOVADUTRA - 15 %, AFD - 12% e ALS - 11,5% </font>**

# %%
df[df['Vitimas'] == 1]['Concessionaria'].value_counts(normalize=True)
# Out:
# NOVADUTRA           0.149311
# AFD                 0.121984
# ALS                 0.115191
# ARB                 0.076931
# AF                  0.066197
# CONCER              0.061541
# CONCEBRA            0.056296
# VIA BAHIA           0.056161
# ECO-101             0.049191
# VIA040              0.044346
# CRO                 0.035761
# CRT                 0.035357
# APS                 0.027487
# AÇO                 0.021923
# TRANSBRASILIANA     0.019222
# MSVIA               0.018541
# ECO050              0.017990
# ECOSUL              0.017906
# ECOPONTE            0.004589
# VIASUL              0.003176
# ECOVIASDOCERRADO    0.000900
# Name: Concessionaria, dtype: float64

# %%
plt.figure(figsize=(25,12))
amount = 100* df[df['Vitimas'] == 1]['Concessionaria'].value_counts(normalize=True)
sns.barplot(x=amount.keys(), y=amount);
plt.xlabel('Concessionaria')
plt.ylabel('Percentual Vitimas')
plt.xticks(rotation=90);

# %% [markdown]
# ### Qual e o Percentual de Acidentes com vitimas fatais?
# **<font color=red>2% dos Acidentes Possuem pelos menos uma vitima Fatal</font>**

# %%
df['Fatal']  = df['Mortos'].apply(lambda x: 1 if (float(x) >0  )else 0)

# %%
df['Fatal'].value_counts( normalize=True)
# Out:
# 0    0.979611
# 1    0.020389
# Name: Fatal, dtype: float64

# %%
plt.rcdefaults()
f,ax = plt.subplots(1,2, figsize=(10,5))
df['Fatal'].value_counts().plot.pie(explode=[0,0.1], autopct='%1.1f%%', ax=ax[0], shadow=True)
ax[0].set_title('Vitimas Fatais')
ax[0].set_ylabel('')
sns.countplot('Fatal', data=df, ax=ax[1])
ax[1].set_title('Vitimas Fatais')
plt.show()

# %% [markdown]
# ### Quais São as 3 Concessionarias Responsaveis pelos trechos onde  ocorre o maior número de acidente com Vitimas Fatais?
# **<font color='red'>NOVADUTRA - 12,8%, AFD - 11% e VIA BAHIA- 10% </font>**

# %%
df[df['Fatal']==1]['Concessionaria'].value_counts(normalize=True)
# Out:
# NOVADUTRA           0.128824
# AFD                 0.110340
# VIA BAHIA           0.098584
# ALS                 0.096105
# ARB                 0.082720
# AF                  0.081232
# CONCEBRA            0.056870
# ECO-101             0.053470
# VIA040              0.052691
# CRO                 0.041289
# APS                 0.039802
# CONCER              0.036331
# TRANSBRASILIANA     0.023654
# ECOSUL              0.023088
# CRT                 0.022592
# MSVIA               0.018414
# AÇO                 0.017564
# ECO050              0.012606
# VIASUL              0.002195
# ECOPONTE            0.001133
# ECOVIASDOCERRADO    0.000496
# Name: Concessionaria, dtype: float64

# %%
plt.figure(figsize=(25,12))
amount = 100 *df[df['Fatal']==1]['Concessionaria'].value_counts(normalize=True)
sns.barplot(x=amount.keys(), y=amount)
plt.ylabel('Percentual de Vitimas Fatais')
plt.xlabel('Concessionaria')
plt.xticks(rotation=90);

# %% [markdown]
# ### Em Quais sentidos ocorrem o maior número de acidentes com vitimas?
# **<font color='red'> Norte - 47,8% e Sul - 46,8%</font>**

# %%
df['Sentido'] = df['Sentido'].apply(lambda x: str(x).upper())
df['Sentido'] = df['Sentido'].apply(lambda x: 'SUL' if('SUL' in x or 'S' == x)else 'NORTE' if('NORTE' in x or 'N' == x) else x)

# %%
df['Sentido'].value_counts(normalize=True)
# Out:
# NORTE    0.478205
# SUL      0.468924
# LESTE    0.024280
# OESTE    0.023228
# NAN      0.002451
# RJ       0.001825
# JF       0.000994
# AMBOS    0.000094
# Name: Sentido, dtype: float64

# %%
df[df['Fatal'] == 1]['Sentido'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
df[df['Vitimas'] == 1]['Sentido'].value_counts(normalize=True)
# Out:
# NORTE    0.478744
# SUL      0.468468
# LESTE    0.023702
# OESTE    0.022204
# NAN      0.003466
# RJ       0.002330
# JF       0.001001
# AMBOS    0.000084
# Name: Sentido, dtype: float64

# %%
df[df['Vitimas'] == 1]['Sentido'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ###  Quais os tipos de Acidentes com maior possibilidade de ter pelo menos uma vitima Fatal?

# %%
df['TipoDeAcidente'] = df['TipoDeAcidente'].apply(lambda x: str(x).upper())
df['TipoDeAcidente'] = df['TipoDeAcidente'].apply(lambda x: 'ATROPELAMENTO' if('ATROP' in x  ) else
                                                  'COLISÃO' if('COLISÃO' in x or 'COLISAO' in x ) else 
                                                 'CHOQUE' if ('CHOQUE' in x)else  'ABALROAMENTO' if('ABAL' in x or 'ABLR' in x ) else
                                                 'QUEDA' if ('QUED' in x ) else  'OUTROS' if('OUTR' in x) else 
                                                 'SAIDA DE PISTA' if ('PISTA' in x) else x)

# %%
x= df[df['Fatal']==1]['TipoDeAcidente'].value_counts()
df[df['Fatal']==1]['TipoDeAcidente'].value_counts(normalize = True)
# Out:
# COLISÃO                          0.366431
# ATROPELAMENTO                    0.316076
# CAPOTAMENTO                      0.060482
# CHOQUE                           0.059419
# TOMBAMENTO                       0.041289
# QUEDA                            0.041006
# SAIDA DE PISTA                   0.038527
# OUTROS                           0.029958
# ABALROAMENTO                     0.023088
# ENGAVETAMENTO                    0.016785
# DERRAPAGEM                       0.001700
# SEQUÊNCIA                        0.001416
# TOMBAMENTO DE MOTO               0.001416
# NAN                              0.000637
# SUL                              0.000567
# NORTE                            0.000496
# OBJETO LANÇADO CONTRA VEÍCULO    0.000354
# NÃO DEF                          0.000142
# CARRETA DEU L                    0.000071
# DANOS EVENTUAIS                  0.000071
# SUBMERSÃO                        0.000071
# Name: TipoDeAcidente, dtype: float64

# %%
plt.rcdefaults()
fig, ax = plt.subplots()

y_pos = np.arange(len(x))

ax.barh(y_pos, x, align='center', color='blue')
ax.set_yticks(y_pos)
ax.set_yticklabels(x.keys())
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Acidentes')
ax.set_title('Tipos De Acidentes Com pelo menos uma Vitima Fatal')

plt.show()

# %%
#plt.plot(x.keys(), x, 'o', color='black');
#plt.xticks(rotation=90);

# %% [markdown]
# ### Veiculos Envolvidos em Acidentes Fatais

# %%
df['Automovel'] = df['Automovel'].apply(lambda x: float(0) if(str(x).strip() == '') else float(x))
df['Caminhao'] = df['Caminhao'].apply(lambda x: float(0) if(str(x).strip() == '') else float(x))
df['Moto'] = df['Moto'].apply(lambda x: float(0) if(str(x).strip() == '') else float(x))
df['Transp__Cargas_Especiais'] = df['Transp__Cargas_Especiais'].apply(lambda x: float(0) if(str(x).strip() == '') else float(x))
df['Utilitario'] = df['Utilitario'].apply(lambda x: float(0) if(str(x).strip() == '') else float(x))
df['Automovel'].value_counts()
# Out:
# 1.0     371065
# 2.0      95609
# 0.0      49690
# 3.0      21357
# 4.0       5816
# 5.0       1608
# 6.0        549
# 7.0        187
# 8.0         64
# 9.0         33
# 10.0        10
# 11.0         7
# 12.0         5
# 13.0         3
# 15.0         2
# 14.0         1
# Name: Automovel, dtype: int64

# %%
df.plot.density(y='Automovel', xlim=(0,15), figsize=(6,3))
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df_fatal = df[df['Fatal'] ==1]

# %%
veiculos = ['Automovel', 'Bicicleta', 'Caminhao', 'Moto', 'Onibus', 'Outros',
       'Tracao_animal', 'Transp__Cargas_Especiais', 'Trator__maquinas',
       'Utilitario']
df_veiculos = []
for i in  range(len(veiculos)):
    percentual = df_fatal[veiculos[i]].count() /df_fatal.shape[0]
    df_veiculos.append([veiculos[i], percentual])
df2 = pd.DataFrame(np.array(df_veiculos), columns=['Veiculo', 'Percentual'])

# %%
plt.figure(figsize=(8,5))
df2['Percentual'] = df2['Percentual'].astype(float)
sns.barplot(x='Veiculo', y = 'Percentual', data= df2)
plt.xticks(rotation=90);

# %% [markdown]
# ### Evolução de Acidentes com Vitimas Fatais ao Longo dos Anos

# %%
df['Data'] = pd.to_datetime(df['Data'] )
df['year'] = df['Data'].dt.year
df = df[df['year']<2021]
df_fatal = df[df['Fatal'] ==1]
df_vitimas = df[df['Vitimas'] ==1]

# %%
#df.groupby(df['Data'].dt.to_period('M'))['No_DaOcorrencia'].count().plot.bar()
#df = df[df['year']<2021]
fatal = df.groupby(df_fatal['year'])['No_DaOcorrencia'].count()
vitimas = df.groupby(df_vitimas['year'])['No_DaOcorrencia'].count()

# %%
f, ax = plt.subplots(1,2, figsize=(10,4))
fatal.plot.line(ax=ax[0])
ax[0].set_title('Vitimas Fatais')
ax[0].set_xlabel('Ano')
vitimas.plot.line(ax=ax[1])
ax[1].set_xlabel('Ano')
ax[1].set_title('Vitimas Envolvidas Em acidentes');

# %%
result= pd.merge(fatal.to_frame(), vitimas.to_frame(),on="year" )
result = result.rename(columns={'No_DaOcorrencia_x': 'Fatais'})
result = result.rename(columns={'No_DaOcorrencia_y': 'Vitimas'})

# %%
sns.lineplot(data=result);
